# %%
#!pip install -e [extra]
#!pip install tensorboard
# !pip install tensorflow
# !pip install git+https://github.com/carlosluis/stable-baselines3@fix_tests 
# !pip install pyglet
# !pip install gym['classic_control']
#pip install --user --upgrade git+http://github.com/pyglet/pyglet@pyglet-1.5-maintenance
#!pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cpu
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 805.3 kB/s eta 0:00:0000:0100:05
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.9 MB/s eta 0:00:00
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 3.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.1.21-py2.py3-none-any.whl (26 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.8.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 3.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow) (23.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-15.0.6.1-py2.py3-none-manylinux2010_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 3.8 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 6.8 MB/s eta 0:00:0000:0100:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.51.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 3.4 MB/s eta 0:00:0000:0100:01
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow) (67.1.0)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.15.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 2.3 MB/s eta 0:00:00
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.8 MB/s eta 0:00:0000:0100:01
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.0 MB/s eta 0:00:0000:0100:01m
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 4.5 MB/s eta 0:00:0000:0100:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 3.0 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 10.8 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 3.8 MB/s eta 0:00:0000:0100:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.16.1-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 2.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.2)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 5.3 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.2)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, opt-einsum, markdown, keras, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.12
#     Uninstalling protobuf-4.21.12:
#       Successfully uninstalled protobuf-4.21.12
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 flatbuffers-23.1.21 gast-0.4.0 google-auth-2.16.1 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.3 keras-2.11.0 libclang-15.0.6.1 markdown-3.4.1 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.2.0 werkzeug-2.2.3 wrapt-1.15.0
# Collecting git+https://github.com/carlosluis/stable-baselines3@fix_tests
#   Cloning https://github.com/carlosluis/stable-baselines3 (to revision fix_tests) to /tmp/pip-req-build-kl22aqog
#   Running command git clone --filter=blob:none --quiet https://github.com/carlosluis/stable-baselines3 /tmp/pip-req-build-kl22aqog
#   Running command git checkout -b fix_tests --track origin/fix_tests
#   Switched to a new branch 'fix_tests'
#   Branch 'fix_tests' set up to track remote branch 'fix_tests' from 'origin'.
#   Resolved https://github.com/carlosluis/stable-baselines3 to commit c5a5d732ee8743c512bf14cb338c4fc2c9b80ec3
#   Preparing metadata (setup.py) ... done
# Collecting gym==0.26.2
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 3.1 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from stable-baselines3==2.0.0a0) (1.23.5)
# Collecting torch>=1.11
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 400.0 kB/s eta 0:00:0000:0100:08
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from stable-baselines3==2.0.0a0) (2.2.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from stable-baselines3==2.0.0a0) (1.5.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from stable-baselines3==2.0.0a0) (3.6.3)
# Collecting importlib-metadata~=4.13
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Collecting gym-notices>=0.0.4
#   Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata~=4.13->stable-baselines3==2.0.0a0) (3.13.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 3.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3==2.0.0a0) (4.4.0)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 1.1 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 706.4 kB/s eta 0:00:0000:0100:04
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3==2.0.0a0) (0.38.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3==2.0.0a0) (67.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3==2.0.0a0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3==2.0.0a0) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3==2.0.0a0) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3==2.0.0a0) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3==2.0.0a0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3==2.0.0a0) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3==2.0.0a0) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3==2.0.0a0) (9.4.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->stable-baselines3==2.0.0a0) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a0) (1.16.0)
# Building wheels for collected packages: stable-baselines3, gym
#   Building wheel for stable-baselines3 (setup.py) ... done
#   Created wheel for stable-baselines3: filename=stable_baselines3-2.0.0a0-py3-none-any.whl size=174426 sha256=9ffdef5c57d8b2497ef253915c9a7bc3661489201db84dd58db0eb27cd47ad8a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hi8yivxq/wheels/cc/40/56/e6db2f8ff9427b0849f4c6ddbe003a53a5f61f31aae2f9ccb7
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827636 sha256=2dcf49a896b50bbb3ec203071ebab6ebfa2c0f6c9f90d9d483485223fd1b5169
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
# Successfully built stable-baselines3 gym
# Installing collected packages: gym-notices, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, importlib-metadata, gym, nvidia-cudnn-cu11, torch, stable-baselines3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
# Successfully installed gym-0.26.2 gym-notices-0.0.8 importlib-metadata-4.13.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 stable-baselines3-2.0.0a0 torch-1.13.1
# Collecting pyglet
#   Downloading pyglet-2.0.5-py3-none-any.whl (831 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.3/831.3 kB 2.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pyglet
# Successfully installed pyglet-2.0.5
# Requirement already satisfied: gym[classic_control] in /opt/conda/lib/python3.10/site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/lib/python3.10/site-packages (from gym[classic_control]) (1.23.5)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from gym[classic_control]) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gym[classic_control]) (2.2.1)
# Collecting pygame==2.1.0
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 3.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pygame
# Successfully installed pygame-2.1.0

# %%
import os
import gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
# %load_ext tensorboard

# %%
os.environ["SDL_VIDEODRIVER"] = "dummy"

# %%
environment_name = 'CartPole-v1'
env = gym.make(environment_name)
environment_name
# Out:
# 'CartPole-v1'

# %%
episodes=10
for episode in range(1, episodes+1):
    state = env.reset()
    truncated = False
    score = 0
    while not truncated:
        env.render()
        action = env.action_space.sample()
        next_state, reward, terminated, truncated , info = env.step(action)
        score += reward
    print('Episone:{} Score:{}'.format( episode, score))
env.close()
# Out:
# /opt/conda/lib/python3.10/site-packages/gym/envs/classic_control/cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(
# Episone:1 Score:29.0
# Episone:2 Score:32.0
# Episone:3 Score:22.0
# Episone:4 Score:17.0
# Episone:5 Score:31.0
# Episone:6 Score:12.0
# Episone:7 Score:24.0
# Episone:8 Score:21.0
# Episone:9 Score:16.0
# Episone:10 Score:13.0

# %%
env.observation_space.sample()
# Out:
# array([ 8.2398462e-01,  2.7396842e+38,  5.6978744e-02, -1.8523515e+38],
#       dtype=float32)

# %%
env.reset()
# Out:
# (array([ 0.02688016, -0.02007901, -0.01611588, -0.01492143], dtype=float32),
#  {})

# %%
env.action_space.sample(), env.action_space
# Out:
# (0, Discrete(2))

# %%
env.step(1)
# Out:
# (array([ 0.02647858,  0.17527032, -0.01641431, -0.31264523], dtype=float32),
#  1.0,
#  False,
#  False,
#  {})

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
log_path = os.path.join('training','logs')
log_path
# Out:
# 'training/logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# 2023-02-28 17:04:29.090383: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 17:04:35.520592: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-02-28 17:04:35.521574: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-02-28 17:04:35.521622: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Logging to training/logs/PPO_9
# -----------------------------
# | time/              |      |
# |    fps             | 102  |
# |    iterations      | 1    |
# |    time_elapsed    | 19   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 2           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008716082 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00133    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.88        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 55.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 3           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007419243 |
# |    clip_fraction        | 0.0484      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.0661      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 41.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 138        |
# |    iterations           | 4          |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00817914 |
# |    clip_fraction        | 0.0949     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.632     |
# |    explained_variance   | 0.216      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.4       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0191    |
# |    value_loss           | 53.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 5           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014820091 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 61.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 146          |
# |    iterations           | 6            |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0049533183 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.596       |
# |    explained_variance   | 0.372        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.6         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 61.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 149          |
# |    iterations           | 7            |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0058553396 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.556        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00898     |
# |    value_loss           | 57           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 151          |
# |    iterations           | 8            |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0073885964 |
# |    clip_fraction        | 0.0815       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00996     |
# |    value_loss           | 34.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 152          |
# |    iterations           | 9            |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0074207205 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.801        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.99         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00551     |
# |    value_loss           | 39.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 154          |
# |    iterations           | 10           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0070708776 |
# |    clip_fraction        | 0.0568       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.564       |
# |    explained_variance   | 0.696        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00615     |
# |    value_loss           | 50.5         |
# ------------------------------------------

# %%
PPO_Path = os.path.join('training','save','PPO_Model_Cartpole')
PPO_Path
# Out:
# 'training/save/PPO_Model_Cartpole'

# %%
model.save(PPO_Path)

# %%
del model

# %%
model = PPO.load(PPO_Path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=20, render=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:208: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (492.5, 19.744619520264248)

# %%
env.close()

# %%
episodes=10
for episode in range(1, episodes+1):
    observation = env.reset()
    terminated = False
    score = 0
    while not terminated:
        env.render()
        action, _ = model.predict(observation)
        observation, reward, terminated , info = env.step(action)
        score += reward
    print('Episone:{} Score:{}'.format( episode, score))
env.close()
# Out:
# Episone:1 Score:[327.]
# Episone:2 Score:[283.]
# Episone:3 Score:[257.]
# Episone:4 Score:[418.]
# Episone:5 Score:[500.]
# Episone:6 Score:[451.]
# Episone:7 Score:[500.]
# Episone:8 Score:[500.]
# Episone:9 Score:[500.]
# Episone:10 Score:[233.]

# %%
log_path
# Out:
# 'training/logs'

# %%
training_log_path = os.path.join('./', log_path)
training_log_path = training_log_path + '/'
training_log_path
# Out:
# './training/logs/'

# %%
#%tensorboard --logdir training_log_path --max_reload_threads 4
#!tensorboard --logdir './training/logs/PPO_3/' --bind_all
#!tensorboard --logdir ./ --bind_all
# !tensorboard --logdir './training/logs/' --bind_all  # training_log_path
# Out:
# 2023-02-28 17:16:03.037919: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 17:16:03.934190: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-28 17:16:03.934894: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-28 17:16:10.247486: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-02-28 17:16:10.248287: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-02-28 17:16:10.248436: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-28 17:16:17.237055: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-02-28 17:16:17.238578: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-28 17:16:17.238887: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (1c188a405dea): /proc/driver/nvidia/version does not exist
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# TensorBoard 2.11.2 at http://1c188a405dea:6006/ (Press CTRL+C to quit)

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('training','save')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
log_path, save_path
# Out:
# ('training/logs', 'training/save')

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to training/logs/PPO_6
# -----------------------------
# | time/              |      |
# |    fps             | 156  |
# |    iterations      | 1    |
# |    time_elapsed    | 13   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 2           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008752664 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00169     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.63        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 47.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 3           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011326138 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0874      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 37.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 4            |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0092386715 |
# |    clip_fraction        | 0.0923       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.636       |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0202      |
# |    value_loss           | 55.1         |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.009552717 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 60.9        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %%
# !tensorboard --logdir './training/logs/' --bind_all
# Out:
# 2023-02-24 03:56:15.908507: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-24 03:56:16.640335: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-24 03:56:16.640548: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-24 03:56:21.897803: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-02-24 03:56:21.899041: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-02-24 03:56:21.899558: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-24 03:56:28.726004: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-02-24 03:56:28.726503: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-24 03:56:28.726680: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (aeddd3e1564d): /proc/driver/nvidia/version does not exist
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# TensorBoard 2.11.2 at http://aeddd3e1564d:6006/ (Press CTRL+C to quit)
# ^C

# %%
net_arch = dict(pi=[128,128,128,128], vf=[128,128,128,128])

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to training/logs/PPO_6
# -----------------------------
# | time/              |      |
# |    fps             | 140  |
# |    iterations      | 1    |
# |    time_elapsed    | 14   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 2           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015254676 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.00129     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.13        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0255     |
# |    value_loss           | 24.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 3           |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015024688 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0328     |
# |    value_loss           | 31.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 4           |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013738649 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 46.4        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=199.60 +/- 0.80
# Episode length: 199.60 +/- 0.80
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 200        |
# |    mean_reward          | 200        |
# | time/                   |            |
# |    total_timesteps      | 10000      |
# | train/                  |            |
# |    approx_kl            | 0.01410009 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.555     |
# |    explained_variance   | 0.562      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.95       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0161    |
# |    value_loss           | 31.9       |
# ----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 59    |
# |    iterations      | 5     |
# |    time_elapsed    | 172   |
# |    total_timesteps | 10240 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 6          |
# |    time_elapsed         | 200        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02313289 |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.523     |
# |    explained_variance   | 0.914      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.35       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0079    |
# |    value_loss           | 12.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 7           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008859212 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.342       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00703    |
# |    value_loss           | 8.88        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 8           |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010334589 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00933    |
# |    value_loss           | 8.05        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 66           |
# |    iterations           | 9            |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0046284897 |
# |    clip_fraction        | 0.093        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.762        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000899    |
# |    value_loss           | 3.9          |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.016307687 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.436      |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.144       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00564    |
# |    value_loss           | 2.48        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 65    |
# |    iterations      | 10    |
# |    time_elapsed    | 310   |
# |    total_timesteps | 20480 |
# ------------------------------

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to training/logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 344      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 67       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 557      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 173      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 508      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 285      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 525      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 372      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 504      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 440      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 489      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 502      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.716    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 488      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 598      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 492      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 661      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 480      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 770      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 502      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 866      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 505      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 958      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 491      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1045     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.461    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 490      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1135     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.425    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 494      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1211     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.378    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 476      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1309     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.353    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 473      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.309    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 475      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.274    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 481      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.231    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 472      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1618     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.198    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 469      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.155    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 455      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.128    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 451      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0904   |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 435      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 434      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 438      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2085     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 440      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 439      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 436      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2311     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 436      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 435      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2465     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 436      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 437      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 440      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2712     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 436      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 436      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2931     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 437      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 439      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 3078     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 442      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3176     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 442      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3240     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 438      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3309     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 436      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 439      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3442     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 437      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 438      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 438      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 436      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 437      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3847     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 433      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3944     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 422      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 416      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 417      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 419      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 421      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4525     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 423      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 422      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 4661     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 423      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 4767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 425      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 4875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 425      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 4955     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 427      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 428      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 426      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5269     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 427      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 428      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 429      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 431      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 5650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 432      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 5742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 431      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 5854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 431      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 5943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 429      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 6016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 430      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 6142     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 429      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 6253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 430      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 6348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 433      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 6433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 430      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 6500     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 426      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 6642     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 427      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 6727     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 426      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 6794     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 427      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 6932     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 423      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 7016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 424      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 7107     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 425      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 7203     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 425      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 7269     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 426      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 7372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 426      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 7439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 425      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 7515     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 424      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 7593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 419      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 7647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 421      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 7729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 421      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 7794     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 421      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 7858     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 420      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 7977     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 420      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 8067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 420      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 8160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 420      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 8217     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 420      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 8296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 421      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 8357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 420      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 8479     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 421      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 8598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 422      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 8681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 422      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 8788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 422      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 8884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 423      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 8976     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 422      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 9097     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 421      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 9194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 421      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 9271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 416      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 9362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 416      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 9449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 417      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 9559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 417      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 9631     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 417      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 9698     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 417      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 9759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 419      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 9919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 420      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 10006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 421      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 10082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 422      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 10205    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 422      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 10261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 424      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 10330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 425      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 10400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 426      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 10519    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 426      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 10597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 427      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 10684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 428      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 10766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 429      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 10880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 428      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 10967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 428      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 11069    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 428      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 11153    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 428      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 11232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 428      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 11367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 428      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 11462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 429      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 11550    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 427      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 11639    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 426      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 11762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 426      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 11848    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 425      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 11915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 422      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 12015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 423      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 12121    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 424      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 12207    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 424      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 12285    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 424      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 12342    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 426      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 12436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 426      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 12496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 423      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 12585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 424      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 12652    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 424      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 12722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 426      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 12834    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 427      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 12896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 427      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 13021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 428      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 13087    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 429      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 13155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 429      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 13240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 430      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 13311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 432      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 13417    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 433      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 15820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 434      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 15905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 433      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 15971    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 433      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 16067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 434      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 16152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 434      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 16204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 435      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 16302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 435      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 16367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 435      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 16469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 436      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 16545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 437      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 16643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 437      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 16727    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 437      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 16833    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 437      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 16911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 436      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 16997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 436      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 17086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 437      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 17171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 437      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 17234    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 437      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 17310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 438      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 17383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 438      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 17474    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 438      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 17555    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 438      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 17637    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 438      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 17699    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 438      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 17780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 438      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 17849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 437      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 17904    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 437      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 18005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 437      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 18086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 438      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 18178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 439      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 18247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 439      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 18329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 440      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 18443    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 441      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 18538    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 442      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 18649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 442      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 18712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 443      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 18771    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 443      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 18849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 444      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 18952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 445      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 19042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 445      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 19128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 446      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 19219    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 447      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 19299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 447      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 19383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 448      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 19464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 449      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 19607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 449      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 19689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 450      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 19772    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 912      |
# |    fps              | 450      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 19820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 916      |
# |    fps              | 451      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 19904    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 451      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 19968    |
# ----------------------------------

# %%
DQN_Path = os.path.join('training','save','DQN_Model_Cartpole')
DQN_Path
# Out:
# 'training/save/DQN_Model_Cartpole'

# %%
model.save(DQN_Path)

# %%
del model

# %%
model = DQN.load(DQN_Path, env=env)

# %%
del model
